# %%
library('gdata')

# %%
Sys.setenv(LANG='en')
mydata=read.table('part-r-00000',sep="\t")

# %% [markdown]
# REFERENCE:http://www.sthda.com/english/wiki/text-mining-and-word-cloud-fundamentals-in-r-5-simple-steps-you-should-know

# %%
library("tm")
library("SnowballC")
library("wordcloud")
library("RColorBrewer")

# %%
mydata=na.omit(mydata)

# %% [markdown]
# NOTE:::SCROLL DOWN THE WARNING MESSAGES IN THE NEXT STEP, THE WORDCLOUD WILL BE PRODUCED BELOW THE WARNING MESSAGES....

# %%
set.seed(1234)
wordcloud(words = mydata$V1, freq = mydata$V2, min.freq = 1,
          max.words=200, random.order=FALSE, rot.per=0.35)
# Out:
# plot without title
