# %%
library('gdata')

# %%
mydata=read.csv('/Users/anandpopat/Desktop/4a.csv')

# %%
mydata=mydata[2:3]
mydata=na.omit(mydata)
colnames(mydata)=c('files','time')
mydata
# Out:
#    files time
# 1    2    10.324
# 2   10    32.702
# 3   20    49.713
# 4   30    76.808
# 5   40   109.436
# 6   50   140.873
# 7   60   201.910
# 8   70   257.205
# 9   80   326.921
# 10  90   355.423
# 11 100   384.966

# %%
library(ggplot2)
ggplot(data=mydata, aes(x=mydata$time, y=mydata$files, group=1)) +
  geom_line()+
  geom_point()
# Out:
# plot without title

# %%
mydata1=read.csv('/Users/anandpopat/Desktop/4b.csv')

# %%
mydata1=mydata1[2:3]
mydata1=na.omit(mydata1)
colnames(mydata1)=c('files','time')
mydata1
# Out:
#    files time
# 1    2     9.583
# 2   10    27.362
# 3   20    48.421
# 4   30    70.655
# 5   40   102.875
# 6   50   135.591
# 7   60   187.488
# 8   70   237.956
# 9   80   290.476
# 10  90   324.924
# 11 100   363.933

# %%
library(ggplot2)
ggplot(data=mydata1, aes(x=mydata1$time, y=mydata1$files, group=1)) +
  geom_line()+
  geom_point()
# Out:
# plot without title
